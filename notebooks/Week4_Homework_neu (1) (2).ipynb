# %% [markdown]
# 1. Dataset einlesen

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\shreyaskitty\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://docs.google.com/spreadsheets/d/1ecopK6oyyb4d_7-QLrCr8YlgFrCetHU7-VQfnYej7JY/export?format=xlsx"
dataset = pd.ExcelFile(url, engine='openpyxl')

sheets = []
for sheet in dataset.sheet_names:
    df = dataset.parse(sheet)
    df["City"] = sheet #adding a column to track from which group is the data
    sheets.append(df)

df = pd.concat(sheets, ignore_index=True)

# %%
df[["City", "days"]] = df["City"].str.split("_", expand=True)

# %%
df
# Out:
#        Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0               0  194.033698     Private room        False          True
# 1               1  344.245776     Private room        False          True
# 2               2  264.101422     Private room        False          True
# 3               3  433.529398     Private room        False          True
# 4               4  485.552926     Private room        False          True
# ...           ...         ...              ...          ...           ...
# 51702        1794  715.938574  Entire home/apt        False         False
# 51703        1795  304.793960  Entire home/apt        False         False
# 51704        1796  637.168969  Entire home/apt        False         False
# 51705        1797  301.054157     Private room        False          True
# 51706        1798  133.230489     Private room        False          True
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                    2              False      1    0                  10
# 1                    4              False      0    0                   8
# 2                    2              False      0    1                   9
# 3                    4              False      0    1                   9
# 4                    2               True      0    0                  10
# ...                ...                ...    ...  ...                 ...
# 51702                6              False      0    1                  10
# 51703                2              False      0    0                   8
# 51704                2              False      0    0                  10
# 51705                2              False      0    0                  10
# 51706                4               True      1    0                  10
#
#        ...      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0      ...  5.022964    2.539380   78.690379         4.166708   98.253896
# 1      ...  0.488389    0.239404  631.176378        33.421209  837.280757
# 2      ...  5.748312    3.651621   75.275877         3.985908   95.386955
# 3      ...  0.384862    0.439876  493.272534        26.119108  875.033098
# 4      ...  0.544738    0.318693  552.830324        29.272733  815.305740
# ...    ...       ...         ...         ...              ...         ...
# 51702  ...  0.530181    0.135447  219.402478        15.712158  438.756874
# 51703  ...  0.810205    0.100839  204.970121        14.678608  342.182813
# 51704  ...  0.994051    0.202539  169.073402        12.107921  282.296424
# 51705  ...  3.044100    0.287435  109.236574         7.822803  158.563398
# 51706  ...  1.263932    0.480903  150.450381        10.774264  225.247293
#
#        rest_index_norm       lng       lat       City      days
# 0             6.846473   4.90569  52.41772  amsterdam  weekdays
# 1            58.342928   4.90005  52.37432  amsterdam  weekdays
# 2             6.646700   4.97512  52.36103  amsterdam  weekdays
# 3            60.973565   4.89417  52.37663  amsterdam  weekdays
# 4            56.811677   4.90051  52.37508  amsterdam  weekdays
# ...                ...       ...       ...        ...       ...
# 51702        10.604584  16.37940  48.21136     vienna  weekends
# 51703         8.270427  16.38070  48.20296     vienna  weekends
# 51704         6.822996  16.38568  48.20460     vienna  weekends
# 51705         3.832416  16.34100  48.19200     vienna  weekends
# 51706         5.444140  16.39066  48.20811     vienna  weekends
#
# [51707 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51707 entries, 0 to 51706
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  51707 non-null  int64
#  1   realSum                     51707 non-null  float64
#  2   room_type                   51707 non-null  object
#  3   room_shared                 51707 non-null  bool
#  4   room_private                51707 non-null  bool
#  5   person_capacity             51707 non-null  int64
#  6   host_is_superhost           51707 non-null  bool
#  7   multi                       51707 non-null  int64
#  8   biz                         51707 non-null  int64
#  9   cleanliness_rating          51707 non-null  int64
#  10  guest_satisfaction_overall  51707 non-null  int64
#  11  bedrooms                    51707 non-null  int64
#  12  dist                        51707 non-null  float64
#  13  metro_dist                  51707 non-null  float64
#  14  attr_index                  51707 non-null  float64
#  15  attr_index_norm             51707 non-null  float64
#  16  rest_index                  51707 non-null  float64
#  17  rest_index_norm             51707 non-null  float64
#  18  lng                         51707 non-null  float64
#  19  lat                         51707 non-null  float64
#  20  City                        51707 non-null  object
#  21  days                        51707 non-null  object
# dtypes: bool(3), float64(9), int64(7), object(3)
# memory usage: 7.6+ MB

# %% [markdown]
# 2. Basic Cleaning

# %% [markdown]
# ## Add column for country

# %%
df["City"].unique()
# Out:
# array(['amsterdam', 'athens', 'berlin', 'barcelona', 'budapest', 'lisbon',
#        'london', 'paris', 'rome', 'vienna'], dtype=object)

# %%
# map cities to countries
city_to_country = {
    "amsterdam": "Netherlands",
    "athens": "Greece",
    "berlin": "Germany",
    "barcelona": "Spain",
    "budapest": "Hungary",
    "lisbon": "Portugal",
    "london": "United Kingdom",
    "paris": "France",
    "rome": "Italy",
    "vienna": "Austria"
}

# create new column
df["country"] = df["City"].map(city_to_country)

# test if it worked
print(df[["City", "country", "days"]].head())
# Out:
#         City      country      days
# 0  amsterdam  Netherlands  weekdays
# 1  amsterdam  Netherlands  weekdays
# 2  amsterdam  Netherlands  weekdays
# 3  amsterdam  Netherlands  weekdays
# 4  amsterdam  Netherlands  weekdays

# %%
df.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                2              False      1    0                  10  ...
# 1                4              False      0    0                   8  ...
# 2                2              False      0    1                   9  ...
# 3                4              False      0    1                   9  ...
# 4                2               True      0    0                  10  ...
#
#    metro_dist  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 0    2.539380   78.690379         4.166708   98.253896         6.846473
# 1    0.239404  631.176378        33.421209  837.280757        58.342928
# 2    3.651621   75.275877         3.985908   95.386955         6.646700
# 3    0.439876  493.272534        26.119108  875.033098        60.973565
# 4    0.318693  552.830324        29.272733  815.305740        56.811677
#
#        lng       lat       City      days      country
# 0  4.90569  52.41772  amsterdam  weekdays  Netherlands
# 1  4.90005  52.37432  amsterdam  weekdays  Netherlands
# 2  4.97512  52.36103  amsterdam  weekdays  Netherlands
# 3  4.89417  52.37663  amsterdam  weekdays  Netherlands
# 4  4.90051  52.37508  amsterdam  weekdays  Netherlands
#
# [5 rows x 23 columns]

# %%
df["country"].describe()
# Out:
# count              51707
# unique                10
# top       United Kingdom
# freq                9993
# Name: country, dtype: object

# %% [markdown]
# ## change column name

# %%
# rename column realSum in Price
df = df.rename(columns={"realSum": "Price"})

# test if it worked
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Price', 'room_type', 'room_shared', 'room_private',
#        'person_capacity', 'host_is_superhost', 'multi', 'biz',
#        'cleanliness_rating', 'guest_satisfaction_overall', 'bedrooms', 'dist',
#        'metro_dist', 'attr_index', 'attr_index_norm', 'rest_index',
#        'rest_index_norm', 'lng', 'lat', 'City', 'days', 'country'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0       Price     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                2              False      1    0                  10  ...
# 1                4              False      0    0                   8  ...
# 2                2              False      0    1                   9  ...
# 3                4              False      0    1                   9  ...
# 4                2               True      0    0                  10  ...
#
#    metro_dist  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 0    2.539380   78.690379         4.166708   98.253896         6.846473
# 1    0.239404  631.176378        33.421209  837.280757        58.342928
# 2    3.651621   75.275877         3.985908   95.386955         6.646700
# 3    0.439876  493.272534        26.119108  875.033098        60.973565
# 4    0.318693  552.830324        29.272733  815.305740        56.811677
#
#        lng       lat       City      days      country
# 0  4.90569  52.41772  amsterdam  weekdays  Netherlands
# 1  4.90005  52.37432  amsterdam  weekdays  Netherlands
# 2  4.97512  52.36103  amsterdam  weekdays  Netherlands
# 3  4.89417  52.37663  amsterdam  weekdays  Netherlands
# 4  4.90051  52.37508  amsterdam  weekdays  Netherlands
#
# [5 rows x 23 columns]

# %%
# delete first column
df = df.drop(df.columns[0], axis=1)

# test if it worked
print(df.columns)
# Out:
# Index(['Price', 'room_type', 'room_shared', 'room_private', 'person_capacity',
#        'host_is_superhost', 'multi', 'biz', 'cleanliness_rating',
#        'guest_satisfaction_overall', 'bedrooms', 'dist', 'metro_dist',
#        'attr_index', 'attr_index_norm', 'rest_index', 'rest_index_norm', 'lng',
#        'lat', 'City', 'days', 'country'],
#       dtype='object')

# %%
df.head()
# Out:
#         Price     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True                2
# 1  344.245776  Private room        False          True                4
# 2  264.101422  Private room        False          True                2
# 3  433.529398  Private room        False          True                4
# 4  485.552926  Private room        False          True                2
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                  10
# 1              False      0    0                   8
# 2              False      0    1                   9
# 3              False      0    1                   9
# 4               True      0    0                  10
#
#    guest_satisfaction_overall  ...  metro_dist  attr_index  attr_index_norm  \
# 0                          93  ...    2.539380   78.690379         4.166708
# 1                          85  ...    0.239404  631.176378        33.421209
# 2                          87  ...    3.651621   75.275877         3.985908
# 3                          90  ...    0.439876  493.272534        26.119108
# 4                          98  ...    0.318693  552.830324        29.272733
#
#    rest_index  rest_index_norm      lng       lat       City      days  \
# 0   98.253896         6.846473  4.90569  52.41772  amsterdam  weekdays
# 1  837.280757        58.342928  4.90005  52.37432  amsterdam  weekdays
# 2   95.386955         6.646700  4.97512  52.36103  amsterdam  weekdays
# 3  875.033098        60.973565  4.89417  52.37663  amsterdam  weekdays
# 4  815.305740        56.811677  4.90051  52.37508  amsterdam  weekdays
#
#        country
# 0  Netherlands
# 1  Netherlands
# 2  Netherlands
# 3  Netherlands
# 4  Netherlands
#
# [5 rows x 22 columns]

# %% [markdown]
# # Advanced Cleaning

# %% [markdown]
# The Step: "Instead of having two columns of room_shared and room_private, create one with the respective categories." is not clear to me. There is already the variable room_type, which kind of makes room_shared and rooom_private redundant. The research paper states that those are dummy variables. Why cant we just drop them both?

# %% [markdown]
# Delete the dummy variables for the number of listings of each host:

# %%
# create new colomn "host_portfolio"
# "one" if multi and biz are both 0
df["host_portfolio"] = "one"

# If multi is 1, the host has two to four listings
df.loc[df["multi"] == 1, "host_portfolio"] = "two_to_four"

# If biz is 1, the host has more than four listings
df.loc[df["biz"] == 1, "host_portfolio"] = "more_than_four"

# test if it worked
print(df["host_portfolio"].value_counts())
# Out:
# host_portfolio
# one               18534
# more_than_four    18108
# two_to_four       15065
# Name: count, dtype: int64

# %%
# delete dummys
df = df.drop(columns=["multi", "biz"])
print(df.columns)
# Out:
# Index(['Price', 'room_type', 'room_shared', 'room_private', 'person_capacity',
#        'host_is_superhost', 'cleanliness_rating', 'guest_satisfaction_overall',
#        'bedrooms', 'dist', 'metro_dist', 'attr_index', 'attr_index_norm',
#        'rest_index', 'rest_index_norm', 'lng', 'lat', 'City', 'days',
#        'country', 'host_portfolio'],
#       dtype='object')

# %%
# download the dataset to check if everything is correct
df.to_csv("airbnb_cleaned.csv", index=False)

# %%
df.head(7)
# Out:
#         Price     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True                2
# 1  344.245776  Private room        False          True                4
# 2  264.101422  Private room        False          True                2
# 3  433.529398  Private room        False          True                4
# 4  485.552926  Private room        False          True                2
# 5  552.808567  Private room        False          True                3
# 6  215.124317  Private room        False          True                2
#
#    host_is_superhost  cleanliness_rating  guest_satisfaction_overall  \
# 0              False                  10                          93
# 1              False                   8                          85
# 2              False                   9                          87
# 3              False                   9                          90
# 4               True                  10                          98
# 5              False                   8                         100
# 6              False                  10                          94
#
#    bedrooms      dist  ...  attr_index  attr_index_norm  rest_index  \
# 0         1  5.022964  ...   78.690379         4.166708   98.253896
# 1         1  0.488389  ...  631.176378        33.421209  837.280757
# 2         1  5.748312  ...   75.275877         3.985908   95.386955
# 3         2  0.384862  ...  493.272534        26.119108  875.033098
# 4         1  0.544738  ...  552.830324        29.272733  815.305740
# 5         2  2.131420  ...  174.788957         9.255191  225.201662
# 6         1  1.881092  ...  200.167652        10.599010  242.765524
#
#    rest_index_norm      lng       lat       City      days      country  \
# 0         6.846473  4.90569  52.41772  amsterdam  weekdays  Netherlands
# 1        58.342928  4.90005  52.37432  amsterdam  weekdays  Netherlands
# 2         6.646700  4.97512  52.36103  amsterdam  weekdays  Netherlands
# 3        60.973565  4.89417  52.37663  amsterdam  weekdays  Netherlands
# 4        56.811677  4.90051  52.37508  amsterdam  weekdays  Netherlands
# 5        15.692376  4.87699  52.38966  amsterdam  weekdays  Netherlands
# 6        16.916251  4.91570  52.38296  amsterdam  weekdays  Netherlands
#
#    host_portfolio
# 0     two_to_four
# 1             one
# 2  more_than_four
# 3  more_than_four
# 4             one
# 5             one
# 6             one
#
# [7 rows x 21 columns]

# %%
df.tail(7)
# Out:
#             Price        room_type  room_shared  room_private  \
# 51700  115.933899     Private room        False          True
# 51701  750.765491  Entire home/apt        False         False
# 51702  715.938574  Entire home/apt        False         False
# 51703  304.793960  Entire home/apt        False         False
# 51704  637.168969  Entire home/apt        False         False
# 51705  301.054157     Private room        False          True
# 51706  133.230489     Private room        False          True
#
#        person_capacity  host_is_superhost  cleanliness_rating  \
# 51700                4              False                   9
# 51701                6              False                  10
# 51702                6              False                  10
# 51703                2              False                   8
# 51704                2              False                  10
# 51705                2              False                  10
# 51706                4               True                  10
#
#        guest_satisfaction_overall  bedrooms      dist  ...  attr_index  \
# 51700                          94         1  3.041932  ...  109.751387
# 51701                          96         3  0.378804  ...  257.494817
# 51702                         100         3  0.530181  ...  219.402478
# 51703                          86         1  0.810205  ...  204.970121
# 51704                          93         1  0.994051  ...  169.073402
# 51705                          87         1  3.044100  ...  109.236574
# 51706                          93         1  1.263932  ...  150.450381
#
#        attr_index_norm  rest_index  rest_index_norm       lng       lat  \
# 51700         7.859670  208.517887         5.039797  16.33970  48.19325
# 51701        18.440080  548.973296        13.268473  16.37825  48.21001
# 51702        15.712158  438.756874        10.604584  16.37940  48.21136
# 51703        14.678608  342.182813         8.270427  16.38070  48.20296
# 51704        12.107921  282.296424         6.822996  16.38568  48.20460
# 51705         7.822803  158.563398         3.832416  16.34100  48.19200
# 51706        10.774264  225.247293         5.444140  16.39066  48.20811
#
#          City      days  country  host_portfolio
# 51700  vienna  weekends  Austria     two_to_four
# 51701  vienna  weekends  Austria  more_than_four
# 51702  vienna  weekends  Austria  more_than_four
# 51703  vienna  weekends  Austria             one
# 51704  vienna  weekends  Austria             one
# 51705  vienna  weekends  Austria             one
# 51706  vienna  weekends  Austria     two_to_four
#
# [7 rows x 21 columns]

# %%
df.sample(7)
# Out:
#             Price        room_type  room_shared  room_private  \
# 28174  206.025542     Private room        False          True
# 19250  105.300188     Private room        False          True
# 51507  229.530421  Entire home/apt        False         False
# 23988  154.989534     Private room        False          True
# 12995  160.031959  Entire home/apt        False         False
# 50563  197.040881     Private room        False          True
# 17266  168.386492     Private room        False          True
#
#        person_capacity  host_is_superhost  cleanliness_rating  \
# 28174                2               True                  10
# 19250                2              False                  10
# 51507                3               True                  10
# 23988                2               True                  10
# 12995                2               True                  10
# 50563                2               True                  10
# 17266                2              False                  10
#
#        guest_satisfaction_overall  bedrooms      dist  ...  attr_index  \
# 28174                          97         1  7.816863  ...  162.397576
# 19250                          93         1  1.257029  ...  173.955675
# 51507                          99         1  1.190916  ...  239.318306
# 23988                          98         1  4.943341  ...  227.174194
# 12995                         100         1  0.584217  ...  336.967058
# 50563                          94         1  2.072600  ...  104.942656
# 17266                          80         1  5.917469  ...  191.351373
#
#        attr_index_norm  rest_index  rest_index_norm       lng       lat  \
# 28174        11.288889  334.646830         5.989595  -0.01668  51.52070
# 19250         5.743023  491.196408        21.968136  -9.13499  38.72310
# 51507        17.138398  386.068676         9.331131  16.36539  48.19935
# 23988        15.791130  510.149619         9.134655  -0.08660  51.54469
# 12995        20.094930  631.465156        47.816484  19.05520  47.50377
# 50563         7.515301  150.745518         3.643461  16.40065  48.20382
# 17266         6.317329  141.614417         6.333525  -9.20602  38.70064
#
#            City      days         country  host_portfolio
# 28174    london  weekends  United Kingdom             one
# 19250    lisbon  weekdays        Portugal  more_than_four
# 51507    vienna  weekends         Austria             one
# 23988    london  weekdays  United Kingdom             one
# 12995  budapest  weekdays         Hungary     two_to_four
# 50563    vienna  weekends         Austria     two_to_four
# 17266    lisbon  weekdays        Portugal     two_to_four
#
# [7 rows x 21 columns]

# %%
df.dtypes
# Out:
# Price                         float64
# room_type                      object
# room_shared                      bool
# room_private                     bool
# person_capacity                 int64
# host_is_superhost                bool
# cleanliness_rating              int64
# guest_satisfaction_overall      int64
# bedrooms                        int64
# dist                          float64
# metro_dist                    float64
# attr_index                    float64
# attr_index_norm               float64
# rest_index                    float64
# rest_index_norm               float64
# lng                           float64
# lat                           float64
# City                           object
# days                           object
# country                        object
# host_portfolio                 object
# dtype: object

# %%
df.describe(include="object")
# Out:
#               room_type    City      days         country host_portfolio
# count             51707   51707     51707           51707          51707
# unique                3      10         2              10              3
# top     Entire home/apt  london  weekends  United Kingdom            one
# freq              32648    9993     26207            9993          18534

# %%
df.describe ()
# Out:
#               Price  person_capacity  cleanliness_rating  \
# count  51707.000000     51707.000000        51707.000000
# mean     279.879591         3.161661            9.390624
# std      327.948386         1.298545            0.954868
# min       34.779339         2.000000            2.000000
# 25%      148.752174         2.000000            9.000000
# 50%      211.343089         3.000000           10.000000
# 75%      319.694287         4.000000           10.000000
# max    18545.450285         6.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms          dist    metro_dist  \
# count                51707.000000  51707.00000  51707.000000  51707.000000
# mean                    92.628232      1.15876      3.191285      0.681540
# std                      8.945531      0.62741      2.393803      0.858023
# min                     20.000000      0.00000      0.015045      0.002301
# 25%                     90.000000      1.00000      1.453142      0.248480
# 50%                     95.000000      1.00000      2.613538      0.413269
# 75%                     99.000000      1.00000      4.263077      0.737840
# max                    100.000000     10.00000     25.284557     14.273577
#
#          attr_index  attr_index_norm    rest_index  rest_index_norm  \
# count  51707.000000     51707.000000  51707.000000     51707.000000
# mean     294.204105        13.423792    626.856696        22.786177
# std      224.754123         9.807985    497.920226        17.804096
# min       15.152201         0.926301     19.576924         0.592757
# 25%      136.797385         6.380926    250.854114         8.751480
# 50%      234.331748        11.468305    522.052783        17.542238
# 75%      385.756381        17.415082    832.628988        32.964603
# max     4513.563486       100.000000   6696.156772       100.000000
#
#                 lng           lat
# count  51707.000000  51707.000000
# mean       7.426068     45.671128
# std        9.799725      5.249263
# min       -9.226340     37.953000
# 25%       -0.072500     41.399510
# 50%        4.873000     47.506690
# 75%       13.518825     51.471885
# max       23.786020     52.641410

# %%
total_listing = df['City'].value_counts()
total_listing
# Out:
# City
# london       9993
# rome         9027
# paris        6688
# lisbon       5763
# athens       5280
# budapest     4022
# vienna       3537
# barcelona    2833
# berlin       2484
# amsterdam    2080
# Name: count, dtype: int64

# %%
listing_by_day = df.groupby(['City', 'days']).size().reset_index(name='count')
listing_by_day
# Out:
#          City      days  count
# 0   amsterdam  weekdays   1103
# 1   amsterdam  weekends    977
# 2      athens  weekdays   2653
# 3      athens  weekends   2627
# 4   barcelona  weekdays   1555
# 5   barcelona  weekends   1278
# 6      berlin  weekdays   1284
# 7      berlin  weekends   1200
# 8    budapest  weekdays   2074
# 9    budapest  weekends   1948
# 10     lisbon  weekdays   2857
# 11     lisbon  weekends   2906
# 12     london  weekdays   4614
# 13     london  weekends   5379
# 14      paris  weekdays   3130
# 15      paris  weekends   3558
# 16       rome  weekdays   4492
# 17       rome  weekends   4535
# 18     vienna  weekdays   1738
# 19     vienna  weekends   1799

# %%
# Bar chart for listings per city and day type
listing_by_day.pivot(index='City', columns='days', values='count').plot(kind='bar')
plt.title('Number of Listings per City by Day Type')
plt.ylabel('Number of Listings')
plt.show()

# %%
Proposition = df.groupby('City')['host_is_superhost'].mean().sort_values(ascending=False)
Proposition
# Out:
# City
# athens       0.428598
# budapest     0.378916
# rome         0.326687
# vienna       0.284139
# amsterdam    0.284135
# berlin       0.257246
# lisbon       0.213951
# barcelona    0.181433
# london       0.157410
# paris        0.140700
# Name: host_is_superhost, dtype: float64

# %%
Proposition.plot(kind='bar', title='Proportion of Superhosts by City', ylabel='Proportion', color=plt.cm.Set2.colors, xlabel='City')
# Out:
# <Axes: title={'center': 'Proportion of Superhosts by City'}, xlabel='City', ylabel='Proportion'>

# %%
MF4 = df[df['host_portfolio'] > "more_than_four" ]['City'].value_counts().plot(kind='bar', color=plt.cm.Set3.colors, title='Listings with More Than 4 Rooms by City')

# %%
Entire_home = df[df['room_type'] == 'Entire home/apt']['City'].value_counts()
Entire_home
# Out:
# City
# rome         5561
# paris        5067
# athens       4872
# london       4384
# lisbon       3878
# budapest     3589
# vienna       2747
# amsterdam    1126
# berlin        882
# barcelona     542
# Name: count, dtype: int64

# %%
Entire_home.plot(kind='bar', color=plt.cm.Pastel1.colors, title='Entire Home Listings by City')
# Out:
# <Axes: title={'center': 'Entire Home Listings by City'}, xlabel='City'>

# %%
df['guest_satisfaction_overall'].plot(kind='hist', bins=20, color='skyblue', title='Distribution of Guest Satisfaction (Overall)', edgecolor='black')
plt.xlabel('Guest Satisfaction Overall Score')
plt.ylabel('Number of Listings')
# Out:
# Text(0, 0.5, 'Number of Listings')

# %%
df['guest_satisfaction_overall'].describe()
# Out:
# count    51707.000000
# mean        92.628232
# std          8.945531
# min         20.000000
# 25%         90.000000
# 50%         95.000000
# 75%         99.000000
# max        100.000000
# Name: guest_satisfaction_overall, dtype: float64

# %%
df['cleanliness_rating'].plot(kind='hist', bins=20, color='lightgreen', title='Distribution of Cleanliness Rating', edgecolor='black')
plt.xlabel('Cleanliness Rating Score')
plt.ylabel('Number of Listings')
# Out:
# Text(0, 0.5, 'Number of Listings')

# %%
df['cleanliness_rating'].describe()
# Out:
# count    51707.000000
# mean         9.390624
# std          0.954868
# min          2.000000
# 25%          9.000000
# 50%         10.000000
# 75%         10.000000
# max         10.000000
# Name: cleanliness_rating, dtype: float64

# %%
df['person_capacity'].describe()
capacity_counts = df['person_capacity'].value_counts().sort_index()
capacity_counts.plot(kind='bar', color=plt.cm.Accent.colors, title='Number of Listings by Person Capacity')
plt.xlabel('Person Capacity')
# Out:
# Text(0.5, 0, 'Person Capacity')

# %%
# histograms side-by-side
fig, axes = plt.subplots(1,2, figsize=(12,4))
df[df['days']=='weekdays']['Price'].plot(kind='hist', bins=50, ax=axes[0], edgecolor='black')
axes[0].set_title('Price distribution - Weekdays')
axes[0].set_xlabel('Price')

df[df['days']=='weekends']['Price'].plot(kind='hist', bins=50, ax=axes[1], edgecolor='black')
axes[1].set_title('Price distribution - Weekends')
axes[1].set_xlabel('Price')
plt.tight_layout()
plt.show()

# KDEs overlapping
df.groupby('days')['Price'].plot(kind='kde', legend=True)
plt.title('Price KDE by Days')
plt.xlabel('Price')
plt.show()

# %%
# Plot the distribution of price (former realSum) for both weekday and weekend offers
df.groupby('days')['Price'].plot(kind='kde', legend=True)
plt.show()

# Check normality, skewness, modality
from scipy.stats import skew, shapiro
print("Skewness:", skew(df['Price']))
print("Shapiro-Wilk p-value:", shapiro(df['Price'].sample(5000, random_state=1)).pvalue)

# If skewed, consider using transformations (e.g. log); can you normalize it?
df['log_Price'] = np.log1p(df['Price'])  # log1p = log(1 + x) to avoid log(0)
print("Skewness after log:", skew(df['log_Price']))
df['log_Price'].plot(kind='kde', title='Log-Transformed Price Distribution')
plt.show()
# Out:
# Skewness: 21.419335173717837
# Shapiro-Wilk p-value: 6.067340930023371e-83
# Skewness after log: 0.7172095195989885

# %%
# Difference in price per night between two cities
from scipy import stats
weekdays = df[df['days'] == 'weekdays']
city_pairs = [('london','paris'), ('amsterdam','berlin'), ('rome','athens')]
for c1, c2 in city_pairs:
    prices1 = weekdays[weekdays['City'] == c1]['Price']
    prices2 = weekdays[weekdays['City'] == c2]['Price']

    if prices1.empty or prices2.empty:
        print(f"Skipping {c1} vs {c2} (no data)")
        continue

    t_stat, p_val = stats.ttest_ind(prices1, prices2)

    print(f"{c1} vs {c2} | mean1: {prices1.mean():.2f}, mean2: {prices2.mean():.2f}, p-value: {p_val:.4f}")
    print("Difference is significant" if p_val < 0.05 else "Difference is NOT significant")
# Out:
# london vs paris | mean1: 360.23, mean2: 398.79, p-value: 0.0004
# Difference is significant
# amsterdam vs berlin | mean1: 545.02, mean2: 240.22, p-value: 0.0000
# Difference is significant
# rome vs athens | mean1: 201.62, mean2: 155.87, p-value: 0.0000
# Difference is significant

# %%
# Price per night between weekdays and weekends
df.groupby('days')['Price'].mean().round(2)
# Out:
# days
# weekdays    275.68
# weekends    283.96
# Name: Price, dtype: float64

# %%
# Are superhosts more expensive than normal hosts?
df.groupby('host_is_superhost')['Price'].mean().round(2)
# Out:
# host_is_superhost
# False    288.63
# True     254.45
# Name: Price, dtype: float64

# %%
# Are superhosts closer to the city center and metro station than normal hosts?
df.groupby('host_is_superhost')[['dist', 'metro_dist']].mean().round(3)
# Out:
#                     dist  metro_dist
# host_is_superhost
# False              3.270       0.682
# True               2.962       0.680

# %%
# Are superhosts cleaner than normal hosts?
df.groupby('host_is_superhost')['cleanliness_rating'].mean().round(2)
# Out:
# host_is_superhost
# False    9.24
# True     9.83
# Name: cleanliness_rating, dtype: float64

# %%
#Is there a pattern between room types and superhost status?
df.groupby('room_type')['host_is_superhost'].mean().sort_values(ascending=False).round(3)
# Out:
# room_type
# Entire home/apt    0.274
# Private room       0.227
# Shared room        0.112
# Name: host_is_superhost, dtype: float64

# %%
# Is renting an entire home/apt more expensive than a private room?
df.groupby('room_type')['Price'].mean().round(2)
# Out:
# room_type
# Entire home/apt    324.32
# Private room       204.94
# Shared room        143.57
# Name: Price, dtype: float64

# %%
# Does that depend on the city?
city_room_price = df[df['room_type'].isin(['Entire home/apt', 'Private room'])]
city_room_price.pivot_table(index='City', columns='room_type', values='Price', aggfunc='mean').round(2)
# Out:
# room_type  Entire home/apt  Private room
# City
# amsterdam           734.70        383.47
# athens              155.08        112.84
# barcelona           629.86        214.71
# berlin              363.21        180.52
# budapest            184.57        109.14
# lisbon              282.50        148.90
# london              544.70        220.40
# paris               425.11        299.22
# rome                240.78        148.79
# vienna              256.56        190.43
