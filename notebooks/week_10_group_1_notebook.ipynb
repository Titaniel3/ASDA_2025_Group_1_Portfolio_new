# %%
# Install third-party PCA library (run once)
# !pip install pca
# !pip install plotly
# Out:
# Collecting pca
#   Downloading pca-2.10.1-py3-none-any.whl.metadata (12 kB)
# Collecting datazets (from pca)
#   Downloading datazets-1.1.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: statsmodels in c:\users\daniel3\anaconda\lib\site-packages (from pca) (0.14.4)
# Requirement already satisfied: matplotlib in c:\users\daniel3\anaconda\lib\site-packages (from pca) (3.10.0)
# Requirement already satisfied: numpy in c:\users\daniel3\anaconda\lib\site-packages (from pca) (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\daniel3\anaconda\lib\site-packages (from pca) (1.6.1)
# Requirement already satisfied: scipy in c:\users\daniel3\anaconda\lib\site-packages (from pca) (1.15.3)
# Collecting colourmap>=1.1.19 (from pca)
#   Downloading colourmap-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas in c:\users\daniel3\anaconda\lib\site-packages (from pca) (2.2.3)
# Collecting scatterd>=1.3.7 (from pca)
#   Downloading scatterd-1.4.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting adjusttext (from pca)
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: seaborn in c:\users\daniel3\anaconda\lib\site-packages (from scatterd>=1.3.7->pca) (0.13.2)
# Requirement already satisfied: requests in c:\users\daniel3\anaconda\lib\site-packages (from datazets->pca) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\daniel3\anaconda\lib\site-packages (from matplotlib->pca) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\daniel3\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->pca) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daniel3\anaconda\lib\site-packages (from pandas->pca) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\daniel3\anaconda\lib\site-packages (from pandas->pca) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\daniel3\anaconda\lib\site-packages (from requests->datazets->pca) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daniel3\anaconda\lib\site-packages (from requests->datazets->pca) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\daniel3\anaconda\lib\site-packages (from requests->datazets->pca) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniel3\anaconda\lib\site-packages (from requests->datazets->pca) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\daniel3\anaconda\lib\site-packages (from scikit-learn->pca) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\daniel3\anaconda\lib\site-packages (from scikit-learn->pca) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\daniel3\anaconda\lib\site-packages (from statsmodels->pca) (1.0.1)
# Downloading pca-2.10.1-py3-none-any.whl (34 kB)
# Downloading colourmap-1.2.1-py3-none-any.whl (10 kB)
# Downloading scatterd-1.4.1-py3-none-any.whl (13 kB)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Downloading datazets-1.1.3-py3-none-any.whl (190 kB)
# Installing collected packages: datazets, colourmap, adjusttext, scatterd, pca
#
#    ---------------- ----------------------- 2/5 [adjusttext]
#    ---------------------------------------- 5/5 [pca]
#
# Successfully installed adjusttext-1.3.0 colourmap-1.2.1 datazets-1.1.3 pca-2.10.1 scatterd-1.4.1
# Requirement already satisfied: plotly in c:\users\daniel3\anaconda\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\daniel3\anaconda\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\daniel3\anaconda\lib\site-packages (from plotly) (24.2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from pca import pca
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Load happiness dataset using relative path
df = pd.read_csv("../datasets/happy.csv")

# %% [markdown]
# ## Display first, last and a random sample

# %%
# Show the first rows
display(df.head())

# Show the last rows
display(df.tail())

# Show a random sample of 5 rows
display(df.sample(5))
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 151       0.083                      0.064
# 152       0.270                      0.097
# 153       0.224                      0.106
# 154       0.218                      0.038
# 155       0.149                      0.076
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 65             66            Kosovo  5.662           0.855           1.230
# 127           128           Georgia  4.340           0.853           0.592
# 143           144          Zimbabwe  3.692           0.357           1.094
# 29             30         Guatemala  6.382           0.781           1.268
# 108           109           Senegal  4.631           0.429           1.117
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 65                     0.578                         0.448       0.274
# 127                    0.643                         0.375       0.038
# 143                    0.248                         0.406       0.132
# 29                     0.608                         0.604       0.179
# 108                    0.433                         0.406       0.138
#
#      Perceptions of corruption
# 65                       0.023
# 127                      0.215
# 143                      0.099
# 29                       0.071
# 108                      0.082

# %%
# Overview of column data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# #### Basic Statistics about data

# %%
display(df.describe(include='all'))
# Out:
#         Overall rank Country or region       Score  GDP per capita  \
# count     156.000000               156  156.000000      156.000000
# unique           NaN               156         NaN             NaN
# top              NaN           Finland         NaN             NaN
# freq             NaN                 1         NaN             NaN
# mean       78.500000               NaN    5.375917        0.891449
# std        45.177428               NaN    1.119506        0.391921
# min         1.000000               NaN    2.905000        0.000000
# 25%        39.750000               NaN    4.453750        0.616250
# 50%        78.500000               NaN    5.378000        0.949500
# 75%       117.250000               NaN    6.168500        1.197750
# max       156.000000               NaN    7.632000        2.096000
#
#         Social support  Healthy life expectancy  Freedom to make life choices  \
# count       156.000000               156.000000                    156.000000
# unique             NaN                      NaN                           NaN
# top                NaN                      NaN                           NaN
# freq               NaN                      NaN                           NaN
# mean          1.213237                 0.597346                      0.454506
# std           0.302372                 0.247579                      0.162424
# min           0.000000                 0.000000                      0.000000
# 25%           1.066750                 0.422250                      0.356000
# 50%           1.255000                 0.644000                      0.487000
# 75%           1.463000                 0.777250                      0.578500
# max           1.644000                 1.030000                      0.724000
#
#         Generosity  Perceptions of corruption
# count   156.000000                 156.000000
# unique         NaN                        NaN
# top            NaN                        NaN
# freq           NaN                        NaN
# mean      0.181006                   0.112449
# std       0.098471                   0.096343
# min       0.000000                   0.000000
# 25%       0.109500                   0.051000
# 50%       0.174000                   0.082000
# 75%       0.239000                   0.139000
# max       0.598000                   0.457000

# %%
df.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# ### PCA performed

# %%
df1 = df.copy()
# This creates 3 groups: High, Medium, and Low happiness
y_categories = pd.qcut(df1["Score"], q=3, labels=["Low Happiness", "Medium Happiness", "High Happiness"])

# 2. Prepare X (excluding non-features)
X = df1.drop(columns=["Country or region", "Overall rank", "Score"], errors="ignore")
labels = X.columns

# 3. Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 4. Initialize and Fit
model = pca(n_components=5) 
results = model.fit_transform(X_scaled, col_labels=labels)

# 5. Biplot using the CATEGORIES for coloring
model.biplot(labels=y_categories, legend=True)
# Out:
# [05-01-2026 16:34:32] [pca.pca] [INFO] Row labels are auto-completed.
# [05-01-2026 16:34:32] [pca.pca] [INFO] The PCA reduction is performed on 6 variables (columns) of the input dataframe.
# [05-01-2026 16:34:32] [pca.pca] [INFO] Fit using PCA.
# [05-01-2026 16:34:32] [pca.pca] [INFO] Compute loadings and PCs.
# [05-01-2026 16:34:32] [pca.pca] [INFO] Compute explained variance.
# [05-01-2026 16:34:32] [pca.pca] [INFO] Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[5]
# [05-01-2026 16:34:32] [pca.pca] [INFO] Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [05-01-2026 16:34:32] [pca.pca] [INFO] Outlier detection using SPE/DmodX with n_std=[3]
# [05-01-2026 16:34:32] [pca.pca] [INFO] Plot PC1 vs PC2 with loadings.
# [05-01-2026 16:34:32] [scatterd.scatterd] [INFO] Create scatterplot
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': 'The top 5 Principal Component(s) explains [97.43%] of the variance.'}, xlabel='PC1 (48.8% expl.var)', ylabel='PC2 (23.2% expl.var)'>)

# %%
model.results['topfeat']
# Out:
#     PC                       feature   loading  type
# 0  PC1       Healthy life expectancy  0.507478  best
# 1  PC2                    Generosity  0.677582  best
# 2  PC3  Freedom to make life choices  0.744680  best
# 3  PC4     Perceptions of corruption  0.749989  best
# 4  PC5                Social support  0.756395  best
# 5  PC1                GDP per capita  0.504522  weak

# %%
print(results['variance_ratio'])
# Out:
# [0.48857775 0.23297143 0.09951662 0.09819496 0.05505599]

# %%
print(model.results['explained_var'])
# Out:
# [0.48857775 0.72154919 0.82106581 0.91926077 0.97431676]

# %%
model.plot();

# %%
# 1. Run KMeans
pca_data = results['PC'].iloc[:, :2] 
kmeans = KMeans(n_clusters=3, random_state=42).fit(pca_data)

# 2. Map the numbers to names
# We create a dictionary to define which number corresponds to which label
cluster_map = {0: "Medium Happiness", 1: "Low Happiness", 2: "High Happiness"}

# 3. Apply the map to a new column
df1['Happiness_Level'] = kmeans.labels_
df1['Happiness_Level'] = df1['Happiness_Level'].map(cluster_map)

# 4. Plot using the new named column
fig = px.scatter(pca_data, x='PC1', y='PC2', 
                 color=df1['Happiness_Level'], # Use the names here
                 hover_name=df1['Country or region'],
                 color_discrete_map={
                     "High Happiness": "green",
                     "Medium Happiness": "orange",
                     "Low Happiness": "red"
                 },
                 title="World Happiness Clusters")

fig.show()
# Out:
# c:\Users\Daniel3\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Overall happiness score by country top 10
top_10 = df[['Country or region', 'Score']].sort_values(by='Score', ascending=False).head(10)
plt.figure(figsize=(10,6))
sns.barplot(data=top_10, x='Score', y='Country or region')
plt.title('Top 10 Happiest Countries')
plt.xlabel('Happiness Score')
plt.ylabel('Country or region')
plt.show()

# %%
# 1. Create the map
fig = px.choropleth(df1, 
                    locations="Country or region", 
                    locationmode='country names',
                    color="Happiness_Level", # This is the column we mapped earlier
                    hover_name="Country or region",
                    # Optionally, add the raw score to the hover data
                    hover_data=["Score"],
                    title="Global Happiness Clusters (Based on PCA Analysis)",
                    color_discrete_map={
                        "High Happiness": "#00CC96",   # Green
                        "Medium Happiness": "#EF553B", # Orange
                        "Low Happiness": "#AB63FA"     # Purple
                    },
                    projection="natural earth") # A clean, modern map look

# 2. Update layout for a cleaner look
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0})
fig.show()

# %%
# Define the default factor columns to compare (exclude non-feature columns)
factor_cols = [
    'GDP per capita',
    'Social support',
    'Healthy life expectancy',
    'Freedom to make life choices',
    'Generosity',
    'Perceptions of corruption'
]
# Compute correlation matrix and plot heatmap
corr = df1[factor_cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    vmin=-1,
    vmax=1,
    square=True
)
plt.title("Correlation Between Happiness Factors")
plt.show()

# %% [markdown]
# ## Fill out report

# %%
# Create dataset structure table
structure_table = pd.DataFrame({
    "Feature / Variable": df.columns,
    "Data type": df.dtypes.astype(str),
    "Number of unique values": [df[col].nunique() for col in df.columns],
    "Example values": [df[col].dropna().unique()[:3].tolist() for col in df.columns]
})

structure_table
# Out:
#                                         Feature / Variable Data type  \
# Overall rank                                  Overall rank     int64
# Country or region                        Country or region    object
# Score                                                Score   float64
# GDP per capita                              GDP per capita   float64
# Social support                              Social support   float64
# Healthy life expectancy            Healthy life expectancy   float64
# Freedom to make life choices  Freedom to make life choices   float64
# Generosity                                      Generosity   float64
# Perceptions of corruption        Perceptions of corruption   float64
#
#                               Number of unique values  \
# Overall rank                                      156
# Country or region                                 156
# Score                                             154
# GDP per capita                                    147
# Social support                                    146
# Healthy life expectancy                           143
# Freedom to make life choices                      136
# Generosity                                        122
# Perceptions of corruption                         111
#
#                                           Example values
# Overall rank                                   [1, 2, 3]
# Country or region             [Finland, Norway, Denmark]
# Score                              [7.632, 7.594, 7.555]
# GDP per capita                     [1.305, 1.456, 1.351]
# Social support                      [1.592, 1.582, 1.59]
# Healthy life expectancy            [0.874, 0.861, 0.868]
# Freedom to make life choices       [0.681, 0.686, 0.683]
# Generosity                         [0.202, 0.286, 0.284]
# Perceptions of corruption           [0.393, 0.34, 0.408]

# %%
# Select numeric variables only
numeric_df = df.select_dtypes(include="number")

# Basic descriptive statistics
desc = numeric_df.describe().T

# Add variance column
desc["Variance"] = numeric_df.var()

# Optional: reset index to have variable names as a column
desc = desc.reset_index().rename(columns={"index": "Variable"})

desc
# Out:
#                        Variable  count       mean        std    min       25%  \
# 0                  Overall rank  156.0  78.500000  45.177428  1.000  39.75000
# 1                         Score  156.0   5.375917   1.119506  2.905   4.45375
# 2                GDP per capita  156.0   0.891449   0.391921  0.000   0.61625
# 3                Social support  156.0   1.213237   0.302372  0.000   1.06675
# 4       Healthy life expectancy  156.0   0.597346   0.247579  0.000   0.42225
# 5  Freedom to make life choices  156.0   0.454506   0.162424  0.000   0.35600
# 6                    Generosity  156.0   0.181006   0.098471  0.000   0.10950
# 7     Perceptions of corruption  156.0   0.112449   0.096343  0.000   0.05100
#
#        50%        75%      max     Variance
# 0  78.5000  117.25000  156.000  2041.000000
# 1   5.3780    6.16850    7.632     1.253293
# 2   0.9495    1.19775    2.096     0.153602
# 3   1.2550    1.46300    1.644     0.091429
# 4   0.6440    0.77725    1.030     0.061295
# 5   0.4870    0.57850    0.724     0.026382
# 6   0.1740    0.23900    0.598     0.009696
# 7   0.0820    0.13900    0.457     0.009282
